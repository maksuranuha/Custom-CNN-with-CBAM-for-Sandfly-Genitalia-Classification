# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image
import os
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from skimage import io, transform
from sklearn.model_selection import learning_curve

# Set path to your dataset in Google Drive
dataset_dir = '/content/drive/MyDrive/PAPER DATASET/Genitalia1'  # Update with the correct path

# %%
# Set image parameters
IMAGE_SIZE = 70
BATCH_SIZE = 60
CHANNELS = 3
EPOCHS = 100

# Load the dataset
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)

class_names = dataset.class_names
print(f"In the dataset, there are {len(dataset)} files belonging to {len(class_names)} classes.")

# Display sample images and labels
plt.figure(figsize=(12,12))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        plt.subplot(3, 4, i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# Function to partition the dataset into train, validation, and test sets
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    ds = ds.shuffle(shuffle_size, seed=12)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# Prepare the data for training
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# Define the model architecture
#input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = len(class_names)
# Out:
# Found 1457 files belonging to 6 classes.
# In the dataset, there are 25 files belonging to 6 classes.

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.layers import (GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, BatchNormalization, Add,
                                     Reshape, Multiply, Conv2D, Concatenate, Lambda)
from tensorflow.keras import backend as K

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential


from tensorflow.keras.applications import MobileNetV2

base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
)

base_model.trainable = False



# Full model
model = Sequential([
    layers.Rescaling(1./255, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(n_classes, activation='softmax')
])



input_shape = (70, 70, 3)  # Example
IMAGE_SIZE = 70

#model = customCNN(input_shape, IMAGE_SIZE)
model.summary()
# Out:
# /tmp/ipython-input-3075841789.py:10: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 70, 70, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 3, 3, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │         7,686 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,265,670 (8.64 MB)
#  Trainable params: 7,686 (30.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)


from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

reduce_lr = ReduceLROnPlateau(
    monitor="val_accuracy",
    factor=0.75,
    patience=2,
    min_lr=0.00001
)

# %%
import os

# %%
# Train the model
history = model.fit(
    train_ds,
    epochs=200,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds,
    callbacks=[reduce_lr]
)

# Evaluate the model
scores = model.evaluate(test_ds)
print("Test Loss:", scores[0])
print("Test Accuracy:", scores[1])
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 248s 793ms/step - accuracy: 0.2646 - loss: 2.0345 - val_accuracy: 0.5083 - val_loss: 1.1263 - learning_rate: 0.0010
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6206 - loss: 0.9431 - val_accuracy: 0.6250 - val_loss: 0.8215 - learning_rate: 0.0010
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7346 - loss: 0.6871 - val_accuracy: 0.6917 - val_loss: 0.6953 - learning_rate: 0.0010
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7778 - loss: 0.5935 - val_accuracy: 0.7417 - val_loss: 0.6197 - learning_rate: 0.0010
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8175 - loss: 0.5273 - val_accuracy: 0.7917 - val_loss: 0.5412 - learning_rate: 0.0010
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8589 - loss: 0.4351 - val_accuracy: 0.8167 - val_loss: 0.4985 - learning_rate: 0.0010
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8757 - loss: 0.3787 - val_accuracy: 0.8333 - val_loss: 0.4644 - learning_rate: 0.0010
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8845 - loss: 0.3631 - val_accuracy: 0.8250 - val_loss: 0.4344 - learning_rate: 0.0010
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9167 - loss: 0.3180 - val_accuracy: 0.8583 - val_loss: 0.3971 - learning_rate: 0.0010
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9045 - loss: 0.3125 - val_accuracy: 0.8667 - val_loss: 0.3671 - learning_rate: 0.0010
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9297 - loss: 0.2555 - val_accuracy: 0.8750 - val_loss: 0.3465 - learning_rate: 0.0010
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9507 - loss: 0.2586 - val_accuracy: 0.9000 - val_loss: 0.3218 - learning_rate: 0.0010
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9500 - loss: 0.2340 - val_accuracy: 0.9083 - val_loss: 0.3156 - learning_rate: 0.0010
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9291 - loss: 0.2653 - val_accuracy: 0.9333 - val_loss: 0.2862 - learning_rate: 0.0010
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9590 - loss: 0.2094 - val_accuracy: 0.9333 - val_loss: 0.2737 - learning_rate: 0.0010
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9640 - loss: 0.1863 - val_accuracy: 0.9417 - val_loss: 0.2589 - learning_rate: 0.0010
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9635 - loss: 0.1971 - val_accuracy: 0.9417 - val_loss: 0.2398 - learning_rate: 0.0010
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9664 - loss: 0.1808 - val_accuracy: 0.9500 - val_loss: 0.2387 - learning_rate: 0.0010
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9595 - loss: 0.1779 - val_accuracy: 0.9417 - val_loss: 0.2211 - learning_rate: 0.0010
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9674 - loss: 0.1719 - val_accuracy: 0.9500 - val_loss: 0.2101 - learning_rate: 0.0010
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9768 - loss: 0.1539 - val_accuracy: 0.9417 - val_loss: 0.2041 - learning_rate: 7.5000e-04
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9674 - loss: 0.1489 - val_accuracy: 0.9500 - val_loss: 0.1986 - learning_rate: 7.5000e-04
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9783 - loss: 0.1461 - val_accuracy: 0.9583 - val_loss: 0.1907 - learning_rate: 5.6250e-04
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9684 - loss: 0.1414 - val_accuracy: 0.9583 - val_loss: 0.1893 - learning_rate: 5.6250e-04
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9860 - loss: 0.1217 - val_accuracy: 0.9667 - val_loss: 0.1813 - learning_rate: 5.6250e-04
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9811 - loss: 0.1231 - val_accuracy: 0.9667 - val_loss: 0.1818 - learning_rate: 5.6250e-04
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9783 - loss: 0.1278 - val_accuracy: 0.9667 - val_loss: 0.1756 - learning_rate: 5.6250e-04
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9899 - loss: 0.1214 - val_accuracy: 0.9750 - val_loss: 0.1740 - learning_rate: 4.2187e-04
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9863 - loss: 0.1174 - val_accuracy: 0.9667 - val_loss: 0.1691 - learning_rate: 4.2187e-04
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9873 - loss: 0.1129 - val_accuracy: 0.9667 - val_loss: 0.1669 - learning_rate: 4.2187e-04
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9930 - loss: 0.1051 - val_accuracy: 0.9667 - val_loss: 0.1650 - learning_rate: 3.1641e-04
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9864 - loss: 0.1144 - val_accuracy: 0.9750 - val_loss: 0.1634 - learning_rate: 3.1641e-04
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9888 - loss: 0.1154 - val_accuracy: 0.9667 - val_loss: 0.1606 - learning_rate: 2.3730e-04
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9864 - loss: 0.1160 - val_accuracy: 0.9667 - val_loss: 0.1591 - learning_rate: 2.3730e-04
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9914 - loss: 0.1023 - val_accuracy: 0.9750 - val_loss: 0.1584 - learning_rate: 1.7798e-04
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - loss: 0.1038 - val_accuracy: 0.9750 - val_loss: 0.1578 - learning_rate: 1.7798e-04
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9928 - loss: 0.1003 - val_accuracy: 0.9750 - val_loss: 0.1569 - learning_rate: 1.3348e-04
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9901 - loss: 0.1014 - val_accuracy: 0.9750 - val_loss: 0.1560 - learning_rate: 1.3348e-04
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9900 - loss: 0.1013 - val_accuracy: 0.9750 - val_loss: 0.1555 - learning_rate: 1.0011e-04
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9922 - loss: 0.0938 - val_accuracy: 0.9750 - val_loss: 0.1548 - learning_rate: 1.0011e-04
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9913 - loss: 0.1109 - val_accuracy: 0.9750 - val_loss: 0.1543 - learning_rate: 7.5085e-05
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - loss: 0.1030 - val_accuracy: 0.9750 - val_loss: 0.1539 - learning_rate: 7.5085e-05
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9939 - loss: 0.0952 - val_accuracy: 0.9750 - val_loss: 0.1534 - learning_rate: 5.6314e-05
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9859 - loss: 0.1110 - val_accuracy: 0.9750 - val_loss: 0.1532 - learning_rate: 5.6314e-05
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9885 - loss: 0.1140 - val_accuracy: 0.9750 - val_loss: 0.1530 - learning_rate: 4.2235e-05
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9915 - loss: 0.1036 - val_accuracy: 0.9750 - val_loss: 0.1526 - learning_rate: 4.2235e-05
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9906 - loss: 0.0974 - val_accuracy: 0.9750 - val_loss: 0.1524 - learning_rate: 3.1676e-05
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9920 - loss: 0.1074 - val_accuracy: 0.9750 - val_loss: 0.1522 - learning_rate: 3.1676e-05
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9875 - loss: 0.1046 - val_accuracy: 0.9750 - val_loss: 0.1520 - learning_rate: 2.3757e-05
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9904 - loss: 0.1017 - val_accuracy: 0.9750 - val_loss: 0.1520 - learning_rate: 2.3757e-05
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9903 - loss: 0.0992 - val_accuracy: 0.9750 - val_loss: 0.1518 - learning_rate: 1.7818e-05
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9883 - loss: 0.1151 - val_accuracy: 0.9750 - val_loss: 0.1516 - learning_rate: 1.7818e-05
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9889 - loss: 0.1055 - val_accuracy: 0.9750 - val_loss: 0.1515 - learning_rate: 1.3363e-05
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9927 - loss: 0.0939 - val_accuracy: 0.9750 - val_loss: 0.1514 - learning_rate: 1.3363e-05
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9946 - loss: 0.1007 - val_accuracy: 0.9750 - val_loss: 0.1514 - learning_rate: 1.0023e-05
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9901 - loss: 0.0996 - val_accuracy: 0.9750 - val_loss: 0.1513 - learning_rate: 1.0023e-05
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9931 - loss: 0.0943 - val_accuracy: 0.9750 - val_loss: 0.1512 - learning_rate: 1.0000e-05
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9879 - loss: 0.1085 - val_accuracy: 0.9750 - val_loss: 0.1511 - learning_rate: 1.0000e-05
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9916 - loss: 0.0972 - val_accuracy: 0.9750 - val_loss: 0.1510 - learning_rate: 1.0000e-05
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9900 - loss: 0.1039 - val_accuracy: 0.9750 - val_loss: 0.1510 - learning_rate: 1.0000e-05
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9901 - loss: 0.0990 - val_accuracy: 0.9750 - val_loss: 0.1510 - learning_rate: 1.0000e-05
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9922 - loss: 0.1011 - val_accuracy: 0.9750 - val_loss: 0.1508 - learning_rate: 1.0000e-05
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9901 - loss: 0.1107 - val_accuracy: 0.9750 - val_loss: 0.1508 - learning_rate: 1.0000e-05
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9895 - loss: 0.1119 - val_accuracy: 0.9750 - val_loss: 0.1507 - learning_rate: 1.0000e-05
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9915 - loss: 0.0970 - val_accuracy: 0.9750 - val_loss: 0.1506 - learning_rate: 1.0000e-05
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9933 - loss: 0.0966 - val_accuracy: 0.9750 - val_loss: 0.1506 - learning_rate: 1.0000e-05
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9926 - loss: 0.0988 - val_accuracy: 0.9750 - val_loss: 0.1504 - learning_rate: 1.0000e-05
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9909 - loss: 0.0998 - val_accuracy: 0.9750 - val_loss: 0.1504 - learning_rate: 1.0000e-05
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9884 - loss: 0.1049 - val_accuracy: 0.9750 - val_loss: 0.1504 - learning_rate: 1.0000e-05
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9916 - loss: 0.0965 - val_accuracy: 0.9750 - val_loss: 0.1503 - learning_rate: 1.0000e-05
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.1003 - val_accuracy: 0.9750 - val_loss: 0.1502 - learning_rate: 1.0000e-05
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9917 - loss: 0.0939 - val_accuracy: 0.9750 - val_loss: 0.1500 - learning_rate: 1.0000e-05
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9921 - loss: 0.0976 - val_accuracy: 0.9750 - val_loss: 0.1501 - learning_rate: 1.0000e-05
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9919 - loss: 0.0914 - val_accuracy: 0.9750 - val_loss: 0.1499 - learning_rate: 1.0000e-05
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9905 - loss: 0.0947 - val_accuracy: 0.9750 - val_loss: 0.1499 - learning_rate: 1.0000e-05
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9919 - loss: 0.1042 - val_accuracy: 0.9750 - val_loss: 0.1498 - learning_rate: 1.0000e-05
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9873 - loss: 0.1041 - val_accuracy: 0.9750 - val_loss: 0.1497 - learning_rate: 1.0000e-05
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9896 - loss: 0.1001 - val_accuracy: 0.9750 - val_loss: 0.1496 - learning_rate: 1.0000e-05
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9938 - loss: 0.0944 - val_accuracy: 0.9750 - val_loss: 0.1496 - learning_rate: 1.0000e-05
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9905 - loss: 0.1045 - val_accuracy: 0.9750 - val_loss: 0.1495 - learning_rate: 1.0000e-05
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - loss: 0.0961 - val_accuracy: 0.9750 - val_loss: 0.1493 - learning_rate: 1.0000e-05
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9921 - loss: 0.0981 - val_accuracy: 0.9750 - val_loss: 0.1492 - learning_rate: 1.0000e-05
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9923 - loss: 0.0915 - val_accuracy: 0.9750 - val_loss: 0.1492 - learning_rate: 1.0000e-05
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9896 - loss: 0.0995 - val_accuracy: 0.9750 - val_loss: 0.1490 - learning_rate: 1.0000e-05
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9941 - loss: 0.0957 - val_accuracy: 0.9750 - val_loss: 0.1490 - learning_rate: 1.0000e-05
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9936 - loss: 0.0997 - val_accuracy: 0.9750 - val_loss: 0.1489 - learning_rate: 1.0000e-05
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.0931 - val_accuracy: 0.9750 - val_loss: 0.1488 - learning_rate: 1.0000e-05
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9919 - loss: 0.0953 - val_accuracy: 0.9750 - val_loss: 0.1488 - learning_rate: 1.0000e-05
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9924 - loss: 0.1039 - val_accuracy: 0.9750 - val_loss: 0.1487 - learning_rate: 1.0000e-05
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9897 - loss: 0.0984 - val_accuracy: 0.9750 - val_loss: 0.1486 - learning_rate: 1.0000e-05
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9894 - loss: 0.0958 - val_accuracy: 0.9750 - val_loss: 0.1485 - learning_rate: 1.0000e-05
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.0942 - val_accuracy: 0.9750 - val_loss: 0.1484 - learning_rate: 1.0000e-05
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9923 - loss: 0.0961 - val_accuracy: 0.9750 - val_loss: 0.1483 - learning_rate: 1.0000e-05
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9936 - loss: 0.1009 - val_accuracy: 0.9750 - val_loss: 0.1482 - learning_rate: 1.0000e-05
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9861 - loss: 0.1115 - val_accuracy: 0.9750 - val_loss: 0.1481 - learning_rate: 1.0000e-05
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9898 - loss: 0.0975 - val_accuracy: 0.9750 - val_loss: 0.1481 - learning_rate: 1.0000e-05
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9883 - loss: 0.1015 - val_accuracy: 0.9750 - val_loss: 0.1480 - learning_rate: 1.0000e-05
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9901 - loss: 0.1039 - val_accuracy: 0.9750 - val_loss: 0.1477 - learning_rate: 1.0000e-05
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9925 - loss: 0.0922 - val_accuracy: 0.9750 - val_loss: 0.1478 - learning_rate: 1.0000e-05
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9918 - loss: 0.0907 - val_accuracy: 0.9750 - val_loss: 0.1477 - learning_rate: 1.0000e-05
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9934 - loss: 0.1014 - val_accuracy: 0.9750 - val_loss: 0.1476 - learning_rate: 1.0000e-05
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9936 - loss: 0.0903 - val_accuracy: 0.9750 - val_loss: 0.1475 - learning_rate: 1.0000e-05
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9900 - loss: 0.1005 - val_accuracy: 0.9750 - val_loss: 0.1474 - learning_rate: 1.0000e-05
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9895 - loss: 0.0928 - val_accuracy: 0.9750 - val_loss: 0.1473 - learning_rate: 1.0000e-05
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9931 - loss: 0.0894 - val_accuracy: 0.9750 - val_loss: 0.1472 - learning_rate: 1.0000e-05
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9877 - loss: 0.1008 - val_accuracy: 0.9750 - val_loss: 0.1471 - learning_rate: 1.0000e-05
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9925 - loss: 0.0975 - val_accuracy: 0.9750 - val_loss: 0.1470 - learning_rate: 1.0000e-05
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9888 - loss: 0.1044 - val_accuracy: 0.9750 - val_loss: 0.1469 - learning_rate: 1.0000e-05
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9888 - loss: 0.0964 - val_accuracy: 0.9750 - val_loss: 0.1467 - learning_rate: 1.0000e-05
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9909 - loss: 0.0900 - val_accuracy: 0.9750 - val_loss: 0.1467 - learning_rate: 1.0000e-05
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9932 - loss: 0.0942 - val_accuracy: 0.9750 - val_loss: 0.1466 - learning_rate: 1.0000e-05
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9904 - loss: 0.0918 - val_accuracy: 0.9750 - val_loss: 0.1465 - learning_rate: 1.0000e-05
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9890 - loss: 0.1058 - val_accuracy: 0.9750 - val_loss: 0.1465 - learning_rate: 1.0000e-05
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9897 - loss: 0.0959 - val_accuracy: 0.9750 - val_loss: 0.1464 - learning_rate: 1.0000e-05
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - loss: 0.0963 - val_accuracy: 0.9750 - val_loss: 0.1463 - learning_rate: 1.0000e-05
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9926 - loss: 0.0952 - val_accuracy: 0.9750 - val_loss: 0.1462 - learning_rate: 1.0000e-05
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9937 - loss: 0.0916 - val_accuracy: 0.9750 - val_loss: 0.1459 - learning_rate: 1.0000e-05
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.1052 - val_accuracy: 0.9750 - val_loss: 0.1459 - learning_rate: 1.0000e-05
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9909 - loss: 0.0972 - val_accuracy: 0.9750 - val_loss: 0.1457 - learning_rate: 1.0000e-05
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9894 - loss: 0.0962 - val_accuracy: 0.9750 - val_loss: 0.1457 - learning_rate: 1.0000e-05
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9940 - loss: 0.0865 - val_accuracy: 0.9750 - val_loss: 0.1456 - learning_rate: 1.0000e-05
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9938 - loss: 0.0945 - val_accuracy: 0.9750 - val_loss: 0.1455 - learning_rate: 1.0000e-05
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9899 - loss: 0.0959 - val_accuracy: 0.9750 - val_loss: 0.1455 - learning_rate: 1.0000e-05
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9902 - loss: 0.0951 - val_accuracy: 0.9750 - val_loss: 0.1452 - learning_rate: 1.0000e-05
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9953 - loss: 0.0884 - val_accuracy: 0.9750 - val_loss: 0.1452 - learning_rate: 1.0000e-05
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9935 - loss: 0.0918 - val_accuracy: 0.9750 - val_loss: 0.1450 - learning_rate: 1.0000e-05
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9925 - loss: 0.0939 - val_accuracy: 0.9750 - val_loss: 0.1451 - learning_rate: 1.0000e-05
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9924 - loss: 0.1013 - val_accuracy: 0.9750 - val_loss: 0.1451 - learning_rate: 1.0000e-05
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9930 - loss: 0.0893 - val_accuracy: 0.9750 - val_loss: 0.1448 - learning_rate: 1.0000e-05
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9901 - loss: 0.1002 - val_accuracy: 0.9750 - val_loss: 0.1447 - learning_rate: 1.0000e-05
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.0908 - val_accuracy: 0.9750 - val_loss: 0.1446 - learning_rate: 1.0000e-05
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9885 - loss: 0.1026 - val_accuracy: 0.9750 - val_loss: 0.1445 - learning_rate: 1.0000e-05
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9931 - loss: 0.0958 - val_accuracy: 0.9750 - val_loss: 0.1444 - learning_rate: 1.0000e-05
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - loss: 0.0980 - val_accuracy: 0.9750 - val_loss: 0.1443 - learning_rate: 1.0000e-05
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0896 - val_accuracy: 0.9750 - val_loss: 0.1444 - learning_rate: 1.0000e-05
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9958 - loss: 0.0841 - val_accuracy: 0.9750 - val_loss: 0.1440 - learning_rate: 1.0000e-05
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9934 - loss: 0.0938 - val_accuracy: 0.9750 - val_loss: 0.1440 - learning_rate: 1.0000e-05
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9922 - loss: 0.0930 - val_accuracy: 0.9750 - val_loss: 0.1439 - learning_rate: 1.0000e-05
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9937 - loss: 0.0975 - val_accuracy: 0.9750 - val_loss: 0.1438 - learning_rate: 1.0000e-05
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9940 - loss: 0.0961 - val_accuracy: 0.9750 - val_loss: 0.1436 - learning_rate: 1.0000e-05
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9899 - loss: 0.0983 - val_accuracy: 0.9750 - val_loss: 0.1435 - learning_rate: 1.0000e-05
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9918 - loss: 0.0914 - val_accuracy: 0.9750 - val_loss: 0.1435 - learning_rate: 1.0000e-05
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9934 - loss: 0.0927 - val_accuracy: 0.9750 - val_loss: 0.1433 - learning_rate: 1.0000e-05
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9927 - loss: 0.0917 - val_accuracy: 0.9750 - val_loss: 0.1432 - learning_rate: 1.0000e-05
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9916 - loss: 0.0962 - val_accuracy: 0.9750 - val_loss: 0.1432 - learning_rate: 1.0000e-05
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9908 - loss: 0.1004 - val_accuracy: 0.9750 - val_loss: 0.1430 - learning_rate: 1.0000e-05
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9904 - loss: 0.0989 - val_accuracy: 0.9750 - val_loss: 0.1430 - learning_rate: 1.0000e-05
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9918 - loss: 0.0960 - val_accuracy: 0.9750 - val_loss: 0.1429 - learning_rate: 1.0000e-05
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9926 - loss: 0.0883 - val_accuracy: 0.9750 - val_loss: 0.1427 - learning_rate: 1.0000e-05
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9930 - loss: 0.0933 - val_accuracy: 0.9750 - val_loss: 0.1427 - learning_rate: 1.0000e-05
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9945 - loss: 0.0926 - val_accuracy: 0.9750 - val_loss: 0.1425 - learning_rate: 1.0000e-05
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9917 - loss: 0.0946 - val_accuracy: 0.9750 - val_loss: 0.1423 - learning_rate: 1.0000e-05
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9952 - loss: 0.0845 - val_accuracy: 0.9750 - val_loss: 0.1422 - learning_rate: 1.0000e-05
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9956 - loss: 0.0910 - val_accuracy: 0.9750 - val_loss: 0.1422 - learning_rate: 1.0000e-05
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9936 - loss: 0.0923 - val_accuracy: 0.9750 - val_loss: 0.1420 - learning_rate: 1.0000e-05
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9935 - loss: 0.0859 - val_accuracy: 0.9750 - val_loss: 0.1420 - learning_rate: 1.0000e-05
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9901 - loss: 0.0950 - val_accuracy: 0.9750 - val_loss: 0.1419 - learning_rate: 1.0000e-05
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9923 - loss: 0.0878 - val_accuracy: 0.9750 - val_loss: 0.1417 - learning_rate: 1.0000e-05
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9913 - loss: 0.0886 - val_accuracy: 0.9750 - val_loss: 0.1417 - learning_rate: 1.0000e-05
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.0904 - val_accuracy: 0.9750 - val_loss: 0.1415 - learning_rate: 1.0000e-05
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9910 - loss: 0.0941 - val_accuracy: 0.9750 - val_loss: 0.1414 - learning_rate: 1.0000e-05
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9905 - loss: 0.0989 - val_accuracy: 0.9750 - val_loss: 0.1412 - learning_rate: 1.0000e-05
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9902 - loss: 0.0964 - val_accuracy: 0.9750 - val_loss: 0.1412 - learning_rate: 1.0000e-05
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9946 - loss: 0.0824 - val_accuracy: 0.9750 - val_loss: 0.1411 - learning_rate: 1.0000e-05
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9911 - loss: 0.0933 - val_accuracy: 0.9750 - val_loss: 0.1410 - learning_rate: 1.0000e-05
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9937 - loss: 0.0846 - val_accuracy: 0.9750 - val_loss: 0.1408 - learning_rate: 1.0000e-05
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9904 - loss: 0.0986 - val_accuracy: 0.9750 - val_loss: 0.1408 - learning_rate: 1.0000e-05
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9939 - loss: 0.0896 - val_accuracy: 0.9750 - val_loss: 0.1406 - learning_rate: 1.0000e-05
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.0907 - val_accuracy: 0.9750 - val_loss: 0.1406 - learning_rate: 1.0000e-05
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9908 - loss: 0.0889 - val_accuracy: 0.9750 - val_loss: 0.1403 - learning_rate: 1.0000e-05
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9937 - loss: 0.0963 - val_accuracy: 0.9750 - val_loss: 0.1404 - learning_rate: 1.0000e-05
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9939 - loss: 0.0856 - val_accuracy: 0.9750 - val_loss: 0.1403 - learning_rate: 1.0000e-05
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9950 - loss: 0.0825 - val_accuracy: 0.9750 - val_loss: 0.1400 - learning_rate: 1.0000e-05
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9938 - loss: 0.0879 - val_accuracy: 0.9750 - val_loss: 0.1399 - learning_rate: 1.0000e-05
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9936 - loss: 0.0859 - val_accuracy: 0.9750 - val_loss: 0.1398 - learning_rate: 1.0000e-05
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9929 - loss: 0.0842 - val_accuracy: 0.9750 - val_loss: 0.1398 - learning_rate: 1.0000e-05
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9904 - loss: 0.0939 - val_accuracy: 0.9750 - val_loss: 0.1397 - learning_rate: 1.0000e-05
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9928 - loss: 0.0988 - val_accuracy: 0.9750 - val_loss: 0.1397 - learning_rate: 1.0000e-05
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0847 - val_accuracy: 0.9750 - val_loss: 0.1395 - learning_rate: 1.0000e-05
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9909 - loss: 0.0951 - val_accuracy: 0.9750 - val_loss: 0.1393 - learning_rate: 1.0000e-05
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9934 - loss: 0.0893 - val_accuracy: 0.9750 - val_loss: 0.1391 - learning_rate: 1.0000e-05
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9903 - loss: 0.0921 - val_accuracy: 0.9750 - val_loss: 0.1391 - learning_rate: 1.0000e-05
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9897 - loss: 0.0919 - val_accuracy: 0.9750 - val_loss: 0.1390 - learning_rate: 1.0000e-05
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9901 - loss: 0.0975 - val_accuracy: 0.9750 - val_loss: 0.1389 - learning_rate: 1.0000e-05
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9930 - loss: 0.0890 - val_accuracy: 0.9750 - val_loss: 0.1388 - learning_rate: 1.0000e-05
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9938 - loss: 0.0839 - val_accuracy: 0.9750 - val_loss: 0.1387 - learning_rate: 1.0000e-05
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9912 - loss: 0.0929 - val_accuracy: 0.9750 - val_loss: 0.1386 - learning_rate: 1.0000e-05
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9913 - loss: 0.0930 - val_accuracy: 0.9750 - val_loss: 0.1384 - learning_rate: 1.0000e-05
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9920 - loss: 0.0926 - val_accuracy: 0.9750 - val_loss: 0.1382 - learning_rate: 1.0000e-05
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9954 - loss: 0.0886 - val_accuracy: 0.9750 - val_loss: 0.1382 - learning_rate: 1.0000e-05
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9912 - loss: 0.0926 - val_accuracy: 0.9750 - val_loss: 0.1381 - learning_rate: 1.0000e-05
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9935 - loss: 0.0870 - val_accuracy: 0.9750 - val_loss: 0.1379 - learning_rate: 1.0000e-05
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9975 - loss: 0.0893 - val_accuracy: 0.9750 - val_loss: 0.1378 - learning_rate: 1.0000e-05
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9926 - loss: 0.0916 - val_accuracy: 0.9750 - val_loss: 0.1377 - learning_rate: 1.0000e-05
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9920 - loss: 0.0943 - val_accuracy: 0.9750 - val_loss: 0.1376 - learning_rate: 1.0000e-05
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9946 - loss: 0.0832 - val_accuracy: 0.9750 - val_loss: 0.1375 - learning_rate: 1.0000e-05
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9950 - loss: 0.0858 - val_accuracy: 0.9750 - val_loss: 0.1374 - learning_rate: 1.0000e-05
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9931 - loss: 0.0891 - val_accuracy: 0.9750 - val_loss: 0.1372 - learning_rate: 1.0000e-05
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9942 - loss: 0.0844 - val_accuracy: 0.9750 - val_loss: 0.1372 - learning_rate: 1.0000e-05
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9942 - loss: 0.0936 - val_accuracy: 0.9750 - val_loss: 0.1371 - learning_rate: 1.0000e-05
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9792 - loss: 0.1386
# Test Loss: 0.17732840776443481
# Test Accuracy: 0.9666666388511658

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Plot the training and validation accuracy
plt.figure(figsize=(7, 4))
plt.plot(range(len(history.history['accuracy'])), history.history['accuracy'], label='Training Accuracy')
plt.plot(range(len(history.history['val_accuracy'])), history.history['val_accuracy'], label='Validation Accuracy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# Plot the training and validation loss
plt.figure(figsize=(7, 4))
plt.plot(range(len(history.history['loss'])), history.history['loss'], label='Training Loss')
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], label='Validation Loss')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Make predictions on the test dataset
y_true = []
y_pred = []

for image_batch, label_batch in test_ds:
    predictions = model.predict(image_batch)
    y_true.extend(label_batch.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))  # Get predicted labels

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_true, y_pred)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(11, 12))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.xticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names, rotation=90)
plt.yticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
# Print the classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Classification Report:
#                      precision    recall  f1-score   support
#
# Ph_alexandri_female       0.94      1.00      0.97        32
#   Ph_alexandri_male       1.00      0.93      0.96        40
#  Ph_papatasi_female       1.00      0.95      0.98        21
#    Ph_papatasi_male       0.94      1.00      0.97        32
#  Ph_sergenti_female       1.00      0.97      0.98        29
#    Ph_sergenti_male       0.93      0.96      0.94        26
#
#            accuracy                           0.97       180
#           macro avg       0.97      0.97      0.97       180
#        weighted avg       0.97      0.97      0.97       180

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, jaccard_score
from sklearn.preprocessing import label_binarize

# Make predictions on the test dataset
y_true = []
y_pred = []
y_scores = []  # For ROC curves (probabilities)

for image_batch, label_batch in test_ds:
    predictions = model.predict(image_batch)
    y_true.extend(label_batch.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))  # Predicted class indices
    y_scores.extend(predictions)  # Keep probabilities for ROC

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_scores = np.array(y_scores)

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_true, y_pred)


# Print the classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# -----------------------------
# Compute and plot ROC curves and AUC for each class
# -----------------------------

# Binarize the output for multiclass ROC
y_true_bin = label_binarize(y_true, classes=np.arange(len(class_names)))

plt.figure(figsize=(10, 8))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.title('Class-wise ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Ph_alexandri_female       0.94      1.00      0.97        32
#   Ph_alexandri_male       1.00      0.93      0.96        40
#  Ph_papatasi_female       1.00      0.95      0.98        21
#    Ph_papatasi_male       0.94      1.00      0.97        32
#  Ph_sergenti_female       1.00      0.97      0.98        29
#    Ph_sergenti_male       0.93      0.96      0.94        26
#
#            accuracy                           0.97       180
#           macro avg       0.97      0.97      0.97       180
#        weighted avg       0.97      0.97      0.97       180

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, jaccard_score
from sklearn.preprocessing import label_binarize

# Make predictions on the test dataset
y_true = []
y_pred = []
y_scores = []  # For ROC curves (probabilities)

for image_batch, label_batch in test_ds:
    predictions = model.predict(image_batch)
    y_true.extend(label_batch.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))  # Predicted class indices
    y_scores.extend(predictions)  # Keep probabilities for ROC

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_scores = np.array(y_scores)

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_true, y_pred)

# Print the classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# -----------------------------
# Compute and plot ROC curves and manual AUC for each class
# -----------------------------

# Binarize the output for multiclass ROC
y_true_bin = label_binarize(y_true, classes=np.arange(len(class_names)))

plt.figure(figsize=(10, 8))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])

    # Use np.trapezoid instead of deprecated np.trapz
    roc_auc_manual = np.trapezoid(tpr, fpr)

    plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc_manual:.3f})')


plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.title('Class-wise ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Ph_alexandri_female       0.94      1.00      0.97        32
#   Ph_alexandri_male       1.00      0.93      0.96        40
#  Ph_papatasi_female       1.00      0.95      0.98        21
#    Ph_papatasi_male       0.94      1.00      0.97        32
#  Ph_sergenti_female       1.00      0.97      0.98        29
#    Ph_sergenti_male       0.93      0.96      0.94        26
#
#            accuracy                           0.97       180
#           macro avg       0.97      0.97      0.97       180
#        weighted avg       0.97      0.97      0.97       180

# %%
# -----------------------------
# Compute Jaccard similarity score per class
# -----------------------------

print("\nJaccard Similarity Scores per Class:")

for i, class_name in enumerate(class_names):
    # Jaccard requires binary vectors: treat class i as positive class
    y_true_binary = (y_true == i).astype(int)
    y_pred_binary = (y_pred == i).astype(int)
    jaccard = jaccard_score(y_true_binary, y_pred_binary)
    print(f"{class_name}: {jaccard:.4f}")
# Out:
# Jaccard Similarity Scores per Class:
# Ph_alexandri_female: 0.9412
# Ph_alexandri_male: 0.9250
# Ph_papatasi_female: 0.9524
# Ph_papatasi_male: 0.9412
# Ph_sergenti_female: 0.9655
# Ph_sergenti_male: 0.8929
