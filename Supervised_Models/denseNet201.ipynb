# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image
import os
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from skimage import io, transform
from sklearn.model_selection import learning_curve

# Set path to your dataset in Google Drive
dataset_dir = '/content/drive/MyDrive/PAPER DATASET/Genitalia1'  # Update with the correct path

# %%
# Set image parameters
IMAGE_SIZE = 70
BATCH_SIZE = 60
CHANNELS = 3
EPOCHS = 100

# Load the dataset
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)

class_names = dataset.class_names
print(f"In the dataset, there are {len(dataset)} files belonging to {len(class_names)} classes.")

# Display sample images and labels
plt.figure(figsize=(12,12))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        plt.subplot(3, 4, i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# Function to partition the dataset into train, validation, and test sets
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    ds = ds.shuffle(shuffle_size, seed=12)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# Prepare the data for training
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# Define the model architecture
#input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = len(class_names)
# Out:
# Found 1457 files belonging to 6 classes.
# In the dataset, there are 25 files belonging to 6 classes.

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.layers import (GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, BatchNormalization, Add,
                                     Reshape, Multiply, Conv2D, Concatenate, Lambda)
from tensorflow.keras import backend as K

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K



from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential

base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
base_model.trainable = False


# Full model
model = Sequential([
    layers.Rescaling(1./255, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(n_classes, activation='softmax')
])



input_shape = (70, 70, 3)  # Example
IMAGE_SIZE = 70

#model = customCNN(input_shape, IMAGE_SIZE)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 70, 70, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet201 (Functional)        │ (None, 2, 2, 1920)     │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1920)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │        11,526 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,333,510 (69.94 MB)
#  Trainable params: 11,526 (45.02 KB)
#  Non-trainable params: 18,321,984 (69.89 MB)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)


from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

reduce_lr = ReduceLROnPlateau(
    monitor="val_accuracy",
    factor=0.75,
    patience=2,
    min_lr=0.00001
)

# %%
import os

# %%
# Train the model
history = model.fit(
    train_ds,
    epochs=200,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds,
    callbacks=[reduce_lr]
)

# Evaluate the model
scores = model.evaluate(test_ds)
print("Test Loss:", scores[0])
print("Test Accuracy:", scores[1])
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 301s 3s/step - accuracy: 0.2851 - loss: 2.0833 - val_accuracy: 0.5250 - val_loss: 1.0782 - learning_rate: 0.0010
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6400 - loss: 0.8733 - val_accuracy: 0.6500 - val_loss: 0.7803 - learning_rate: 0.0010
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7552 - loss: 0.6290 - val_accuracy: 0.7833 - val_loss: 0.5763 - learning_rate: 0.0010
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8226 - loss: 0.4965 - val_accuracy: 0.7833 - val_loss: 0.5032 - learning_rate: 0.0010
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8548 - loss: 0.4039 - val_accuracy: 0.8333 - val_loss: 0.4497 - learning_rate: 0.0010
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8879 - loss: 0.3555 - val_accuracy: 0.8750 - val_loss: 0.3854 - learning_rate: 0.0010
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9025 - loss: 0.3067 - val_accuracy: 0.9083 - val_loss: 0.3355 - learning_rate: 0.0010
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9261 - loss: 0.2645 - val_accuracy: 0.9250 - val_loss: 0.2801 - learning_rate: 0.0010
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9453 - loss: 0.2297 - val_accuracy: 0.9333 - val_loss: 0.2379 - learning_rate: 0.0010
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9375 - loss: 0.2310 - val_accuracy: 0.9333 - val_loss: 0.2371 - learning_rate: 0.0010
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9421 - loss: 0.2347 - val_accuracy: 0.9667 - val_loss: 0.2038 - learning_rate: 0.0010
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9613 - loss: 0.1909 - val_accuracy: 0.9750 - val_loss: 0.1879 - learning_rate: 0.0010
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9658 - loss: 0.1724 - val_accuracy: 0.9750 - val_loss: 0.1756 - learning_rate: 0.0010
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9719 - loss: 0.1764 - val_accuracy: 0.9833 - val_loss: 0.1586 - learning_rate: 0.0010
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9795 - loss: 0.1366 - val_accuracy: 0.9833 - val_loss: 0.1533 - learning_rate: 0.0010
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9804 - loss: 0.1424 - val_accuracy: 0.9917 - val_loss: 0.1433 - learning_rate: 0.0010
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9835 - loss: 0.1207 - val_accuracy: 0.9917 - val_loss: 0.1326 - learning_rate: 0.0010
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9902 - loss: 0.1237 - val_accuracy: 0.9833 - val_loss: 0.1244 - learning_rate: 0.0010
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9905 - loss: 0.1048 - val_accuracy: 0.9917 - val_loss: 0.1210 - learning_rate: 7.5000e-04
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9896 - loss: 0.1089 - val_accuracy: 0.9833 - val_loss: 0.1208 - learning_rate: 7.5000e-04
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9951 - loss: 0.0993 - val_accuracy: 0.9917 - val_loss: 0.1215 - learning_rate: 5.6250e-04
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9948 - loss: 0.0929 - val_accuracy: 0.9917 - val_loss: 0.1065 - learning_rate: 5.6250e-04
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9928 - loss: 0.0900 - val_accuracy: 0.9917 - val_loss: 0.1105 - learning_rate: 4.2187e-04
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9946 - loss: 0.0875 - val_accuracy: 0.9917 - val_loss: 0.1031 - learning_rate: 4.2187e-04
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9941 - loss: 0.0918 - val_accuracy: 0.9917 - val_loss: 0.1045 - learning_rate: 3.1641e-04
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9957 - loss: 0.0838 - val_accuracy: 0.9917 - val_loss: 0.1029 - learning_rate: 3.1641e-04
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9950 - loss: 0.0835 - val_accuracy: 0.9917 - val_loss: 0.1013 - learning_rate: 2.3730e-04
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9954 - loss: 0.0859 - val_accuracy: 0.9917 - val_loss: 0.1006 - learning_rate: 2.3730e-04
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9977 - loss: 0.0823 - val_accuracy: 0.9917 - val_loss: 0.1003 - learning_rate: 1.7798e-04
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9935 - loss: 0.0852 - val_accuracy: 0.9917 - val_loss: 0.0989 - learning_rate: 1.7798e-04
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9941 - loss: 0.0883 - val_accuracy: 0.9917 - val_loss: 0.0989 - learning_rate: 1.3348e-04
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9940 - loss: 0.0872 - val_accuracy: 0.9917 - val_loss: 0.0990 - learning_rate: 1.3348e-04
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9955 - loss: 0.0783 - val_accuracy: 0.9917 - val_loss: 0.0966 - learning_rate: 1.0011e-04
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9970 - loss: 0.0784 - val_accuracy: 0.9917 - val_loss: 0.0963 - learning_rate: 1.0011e-04
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9972 - loss: 0.0773 - val_accuracy: 0.9917 - val_loss: 0.0971 - learning_rate: 7.5085e-05
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9969 - loss: 0.0798 - val_accuracy: 0.9917 - val_loss: 0.0960 - learning_rate: 7.5085e-05
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9948 - loss: 0.0831 - val_accuracy: 0.9917 - val_loss: 0.0951 - learning_rate: 5.6314e-05
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9955 - loss: 0.0820 - val_accuracy: 0.9917 - val_loss: 0.0952 - learning_rate: 5.6314e-05
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9979 - loss: 0.0785 - val_accuracy: 0.9917 - val_loss: 0.0951 - learning_rate: 4.2235e-05
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9957 - loss: 0.0758 - val_accuracy: 0.9917 - val_loss: 0.0955 - learning_rate: 4.2235e-05
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9967 - loss: 0.0812 - val_accuracy: 0.9917 - val_loss: 0.0943 - learning_rate: 3.1676e-05
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9977 - loss: 0.0745 - val_accuracy: 0.9917 - val_loss: 0.0945 - learning_rate: 3.1676e-05
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9983 - loss: 0.0761 - val_accuracy: 0.9917 - val_loss: 0.0945 - learning_rate: 2.3757e-05
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9983 - loss: 0.0794 - val_accuracy: 0.9917 - val_loss: 0.0945 - learning_rate: 2.3757e-05
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9965 - loss: 0.0781 - val_accuracy: 0.9917 - val_loss: 0.0943 - learning_rate: 1.7818e-05
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9944 - loss: 0.0802 - val_accuracy: 0.9917 - val_loss: 0.0941 - learning_rate: 1.7818e-05
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9966 - loss: 0.0862 - val_accuracy: 0.9917 - val_loss: 0.0942 - learning_rate: 1.3363e-05
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9950 - loss: 0.0748 - val_accuracy: 0.9917 - val_loss: 0.0941 - learning_rate: 1.3363e-05
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9969 - loss: 0.0733 - val_accuracy: 0.9917 - val_loss: 0.0940 - learning_rate: 1.0023e-05
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9969 - loss: 0.0751 - val_accuracy: 0.9917 - val_loss: 0.0940 - learning_rate: 1.0023e-05
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9989 - loss: 0.0754 - val_accuracy: 0.9917 - val_loss: 0.0939 - learning_rate: 1.0000e-05
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9958 - loss: 0.0779 - val_accuracy: 0.9917 - val_loss: 0.0939 - learning_rate: 1.0000e-05
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9976 - loss: 0.0800 - val_accuracy: 0.9917 - val_loss: 0.0936 - learning_rate: 1.0000e-05
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9959 - loss: 0.0839 - val_accuracy: 0.9917 - val_loss: 0.0936 - learning_rate: 1.0000e-05
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9969 - loss: 0.0710 - val_accuracy: 0.9917 - val_loss: 0.0938 - learning_rate: 1.0000e-05
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9980 - loss: 0.0760 - val_accuracy: 0.9917 - val_loss: 0.0936 - learning_rate: 1.0000e-05
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9983 - loss: 0.0706 - val_accuracy: 0.9917 - val_loss: 0.0936 - learning_rate: 1.0000e-05
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9958 - loss: 0.0696 - val_accuracy: 0.9917 - val_loss: 0.0935 - learning_rate: 1.0000e-05
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9977 - loss: 0.0703 - val_accuracy: 0.9917 - val_loss: 0.0935 - learning_rate: 1.0000e-05
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9982 - loss: 0.0733 - val_accuracy: 0.9917 - val_loss: 0.0933 - learning_rate: 1.0000e-05
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9966 - loss: 0.0789 - val_accuracy: 0.9917 - val_loss: 0.0931 - learning_rate: 1.0000e-05
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9961 - loss: 0.0746 - val_accuracy: 0.9917 - val_loss: 0.0931 - learning_rate: 1.0000e-05
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9959 - loss: 0.0821 - val_accuracy: 0.9917 - val_loss: 0.0932 - learning_rate: 1.0000e-05
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9987 - loss: 0.0710 - val_accuracy: 0.9917 - val_loss: 0.0932 - learning_rate: 1.0000e-05
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9986 - loss: 0.0697 - val_accuracy: 0.9917 - val_loss: 0.0930 - learning_rate: 1.0000e-05
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9948 - loss: 0.0800 - val_accuracy: 0.9917 - val_loss: 0.0932 - learning_rate: 1.0000e-05
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9959 - loss: 0.0763 - val_accuracy: 0.9917 - val_loss: 0.0930 - learning_rate: 1.0000e-05
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9988 - loss: 0.0717 - val_accuracy: 0.9917 - val_loss: 0.0930 - learning_rate: 1.0000e-05
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9971 - loss: 0.0761 - val_accuracy: 0.9917 - val_loss: 0.0928 - learning_rate: 1.0000e-05
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9991 - loss: 0.0690 - val_accuracy: 0.9917 - val_loss: 0.0927 - learning_rate: 1.0000e-05
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9988 - loss: 0.0703 - val_accuracy: 0.9917 - val_loss: 0.0927 - learning_rate: 1.0000e-05
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9973 - loss: 0.0709 - val_accuracy: 0.9917 - val_loss: 0.0926 - learning_rate: 1.0000e-05
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9983 - loss: 0.0739 - val_accuracy: 0.9917 - val_loss: 0.0923 - learning_rate: 1.0000e-05
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9968 - loss: 0.0744 - val_accuracy: 0.9917 - val_loss: 0.0923 - learning_rate: 1.0000e-05
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9966 - loss: 0.0813 - val_accuracy: 0.9917 - val_loss: 0.0924 - learning_rate: 1.0000e-05
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9993 - loss: 0.0714 - val_accuracy: 0.9917 - val_loss: 0.0922 - learning_rate: 1.0000e-05
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9967 - loss: 0.0779 - val_accuracy: 0.9917 - val_loss: 0.0923 - learning_rate: 1.0000e-05
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9983 - loss: 0.0750 - val_accuracy: 0.9917 - val_loss: 0.0922 - learning_rate: 1.0000e-05
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9989 - loss: 0.0724 - val_accuracy: 0.9917 - val_loss: 0.0921 - learning_rate: 1.0000e-05
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9968 - loss: 0.0752 - val_accuracy: 0.9917 - val_loss: 0.0920 - learning_rate: 1.0000e-05
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9968 - loss: 0.0703 - val_accuracy: 0.9917 - val_loss: 0.0920 - learning_rate: 1.0000e-05
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9979 - loss: 0.0763 - val_accuracy: 0.9917 - val_loss: 0.0918 - learning_rate: 1.0000e-05
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9976 - loss: 0.0778 - val_accuracy: 0.9917 - val_loss: 0.0919 - learning_rate: 1.0000e-05
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9967 - loss: 0.0761 - val_accuracy: 0.9917 - val_loss: 0.0917 - learning_rate: 1.0000e-05
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9968 - loss: 0.0728 - val_accuracy: 0.9917 - val_loss: 0.0917 - learning_rate: 1.0000e-05
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9980 - loss: 0.0730 - val_accuracy: 0.9917 - val_loss: 0.0917 - learning_rate: 1.0000e-05
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9972 - loss: 0.0686 - val_accuracy: 0.9917 - val_loss: 0.0916 - learning_rate: 1.0000e-05
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9967 - loss: 0.0794 - val_accuracy: 0.9917 - val_loss: 0.0914 - learning_rate: 1.0000e-05
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9990 - loss: 0.0750 - val_accuracy: 0.9917 - val_loss: 0.0912 - learning_rate: 1.0000e-05
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9966 - loss: 0.0762 - val_accuracy: 0.9917 - val_loss: 0.0911 - learning_rate: 1.0000e-05
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9985 - loss: 0.0684 - val_accuracy: 0.9917 - val_loss: 0.0914 - learning_rate: 1.0000e-05
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9949 - loss: 0.0798 - val_accuracy: 0.9917 - val_loss: 0.0912 - learning_rate: 1.0000e-05
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9982 - loss: 0.0734 - val_accuracy: 0.9917 - val_loss: 0.0910 - learning_rate: 1.0000e-05
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9982 - loss: 0.0684 - val_accuracy: 0.9917 - val_loss: 0.0910 - learning_rate: 1.0000e-05
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9990 - loss: 0.0716 - val_accuracy: 0.9917 - val_loss: 0.0908 - learning_rate: 1.0000e-05
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9972 - loss: 0.0735 - val_accuracy: 0.9917 - val_loss: 0.0907 - learning_rate: 1.0000e-05
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9972 - loss: 0.0671 - val_accuracy: 0.9917 - val_loss: 0.0909 - learning_rate: 1.0000e-05
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9983 - loss: 0.0698 - val_accuracy: 0.9917 - val_loss: 0.0909 - learning_rate: 1.0000e-05
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9982 - loss: 0.0681 - val_accuracy: 0.9917 - val_loss: 0.0905 - learning_rate: 1.0000e-05
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9985 - loss: 0.0763 - val_accuracy: 0.9917 - val_loss: 0.0905 - learning_rate: 1.0000e-05
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9952 - loss: 0.0767 - val_accuracy: 0.9917 - val_loss: 0.0903 - learning_rate: 1.0000e-05
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9966 - loss: 0.0768 - val_accuracy: 0.9917 - val_loss: 0.0906 - learning_rate: 1.0000e-05
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9967 - loss: 0.0732 - val_accuracy: 0.9917 - val_loss: 0.0904 - learning_rate: 1.0000e-05
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9984 - loss: 0.0727 - val_accuracy: 0.9917 - val_loss: 0.0901 - learning_rate: 1.0000e-05
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9965 - loss: 0.0767 - val_accuracy: 0.9917 - val_loss: 0.0900 - learning_rate: 1.0000e-05
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9972 - loss: 0.0707 - val_accuracy: 0.9917 - val_loss: 0.0900 - learning_rate: 1.0000e-05
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9948 - loss: 0.0701 - val_accuracy: 0.9917 - val_loss: 0.0900 - learning_rate: 1.0000e-05
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9965 - loss: 0.0763 - val_accuracy: 0.9917 - val_loss: 0.0898 - learning_rate: 1.0000e-05
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9957 - loss: 0.0754 - val_accuracy: 0.9917 - val_loss: 0.0900 - learning_rate: 1.0000e-05
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9968 - loss: 0.0762 - val_accuracy: 0.9917 - val_loss: 0.0899 - learning_rate: 1.0000e-05
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9983 - loss: 0.0688 - val_accuracy: 0.9917 - val_loss: 0.0895 - learning_rate: 1.0000e-05
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9965 - loss: 0.0749 - val_accuracy: 0.9917 - val_loss: 0.0896 - learning_rate: 1.0000e-05
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9983 - loss: 0.0651 - val_accuracy: 0.9917 - val_loss: 0.0895 - learning_rate: 1.0000e-05
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9978 - loss: 0.0688 - val_accuracy: 0.9917 - val_loss: 0.0893 - learning_rate: 1.0000e-05
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9954 - loss: 0.0744 - val_accuracy: 0.9917 - val_loss: 0.0891 - learning_rate: 1.0000e-05
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9976 - loss: 0.0721 - val_accuracy: 0.9917 - val_loss: 0.0892 - learning_rate: 1.0000e-05
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9971 - loss: 0.0703 - val_accuracy: 0.9917 - val_loss: 0.0892 - learning_rate: 1.0000e-05
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9979 - loss: 0.0669 - val_accuracy: 0.9917 - val_loss: 0.0892 - learning_rate: 1.0000e-05
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9971 - loss: 0.0694 - val_accuracy: 0.9917 - val_loss: 0.0891 - learning_rate: 1.0000e-05
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9982 - loss: 0.0705 - val_accuracy: 0.9917 - val_loss: 0.0889 - learning_rate: 1.0000e-05
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9983 - loss: 0.0696 - val_accuracy: 0.9917 - val_loss: 0.0886 - learning_rate: 1.0000e-05
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9945 - loss: 0.0824 - val_accuracy: 0.9917 - val_loss: 0.0886 - learning_rate: 1.0000e-05
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9978 - loss: 0.0683 - val_accuracy: 0.9917 - val_loss: 0.0889 - learning_rate: 1.0000e-05
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9961 - loss: 0.0690 - val_accuracy: 0.9917 - val_loss: 0.0888 - learning_rate: 1.0000e-05
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9968 - loss: 0.0684 - val_accuracy: 0.9917 - val_loss: 0.0883 - learning_rate: 1.0000e-05
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9989 - loss: 0.0687 - val_accuracy: 0.9917 - val_loss: 0.0885 - learning_rate: 1.0000e-05
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9988 - loss: 0.0673 - val_accuracy: 0.9917 - val_loss: 0.0885 - learning_rate: 1.0000e-05
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9971 - loss: 0.0740 - val_accuracy: 0.9917 - val_loss: 0.0880 - learning_rate: 1.0000e-05
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9985 - loss: 0.0647 - val_accuracy: 0.9917 - val_loss: 0.0880 - learning_rate: 1.0000e-05
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9953 - loss: 0.0781 - val_accuracy: 0.9917 - val_loss: 0.0879 - learning_rate: 1.0000e-05
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9991 - loss: 0.0666 - val_accuracy: 0.9917 - val_loss: 0.0878 - learning_rate: 1.0000e-05
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9974 - loss: 0.0691 - val_accuracy: 0.9917 - val_loss: 0.0877 - learning_rate: 1.0000e-05
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9982 - loss: 0.0679 - val_accuracy: 0.9917 - val_loss: 0.0877 - learning_rate: 1.0000e-05
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9964 - loss: 0.0681 - val_accuracy: 0.9917 - val_loss: 0.0878 - learning_rate: 1.0000e-05
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9969 - loss: 0.0738 - val_accuracy: 0.9917 - val_loss: 0.0874 - learning_rate: 1.0000e-05
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9983 - loss: 0.0724 - val_accuracy: 0.9917 - val_loss: 0.0876 - learning_rate: 1.0000e-05
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9967 - loss: 0.0687 - val_accuracy: 0.9917 - val_loss: 0.0874 - learning_rate: 1.0000e-05
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9972 - loss: 0.0639 - val_accuracy: 0.9917 - val_loss: 0.0875 - learning_rate: 1.0000e-05
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9976 - loss: 0.0750 - val_accuracy: 0.9917 - val_loss: 0.0872 - learning_rate: 1.0000e-05
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9979 - loss: 0.0668 - val_accuracy: 0.9917 - val_loss: 0.0871 - learning_rate: 1.0000e-05
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9946 - loss: 0.0704 - val_accuracy: 0.9917 - val_loss: 0.0872 - learning_rate: 1.0000e-05
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9971 - loss: 0.0673 - val_accuracy: 0.9917 - val_loss: 0.0870 - learning_rate: 1.0000e-05
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9991 - loss: 0.0653 - val_accuracy: 0.9917 - val_loss: 0.0870 - learning_rate: 1.0000e-05
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9959 - loss: 0.0698 - val_accuracy: 0.9917 - val_loss: 0.0868 - learning_rate: 1.0000e-05
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9985 - loss: 0.0699 - val_accuracy: 0.9917 - val_loss: 0.0866 - learning_rate: 1.0000e-05
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9980 - loss: 0.0658 - val_accuracy: 0.9917 - val_loss: 0.0867 - learning_rate: 1.0000e-05
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9986 - loss: 0.0668 - val_accuracy: 0.9917 - val_loss: 0.0864 - learning_rate: 1.0000e-05
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9972 - loss: 0.0726 - val_accuracy: 0.9917 - val_loss: 0.0868 - learning_rate: 1.0000e-05
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9989 - loss: 0.0651 - val_accuracy: 0.9917 - val_loss: 0.0864 - learning_rate: 1.0000e-05
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9978 - loss: 0.0705 - val_accuracy: 0.9917 - val_loss: 0.0865 - learning_rate: 1.0000e-05
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9980 - loss: 0.0650 - val_accuracy: 0.9917 - val_loss: 0.0862 - learning_rate: 1.0000e-05
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9951 - loss: 0.0704 - val_accuracy: 0.9917 - val_loss: 0.0861 - learning_rate: 1.0000e-05
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9987 - loss: 0.0675 - val_accuracy: 0.9917 - val_loss: 0.0859 - learning_rate: 1.0000e-05
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9985 - loss: 0.0685 - val_accuracy: 0.9917 - val_loss: 0.0855 - learning_rate: 1.0000e-05
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9965 - loss: 0.0678 - val_accuracy: 0.9917 - val_loss: 0.0857 - learning_rate: 1.0000e-05
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9988 - loss: 0.0662 - val_accuracy: 0.9917 - val_loss: 0.0856 - learning_rate: 1.0000e-05
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9970 - loss: 0.0689 - val_accuracy: 0.9917 - val_loss: 0.0855 - learning_rate: 1.0000e-05
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9977 - loss: 0.0732 - val_accuracy: 0.9917 - val_loss: 0.0855 - learning_rate: 1.0000e-05
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9988 - loss: 0.0642 - val_accuracy: 0.9917 - val_loss: 0.0855 - learning_rate: 1.0000e-05
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9962 - loss: 0.0724 - val_accuracy: 0.9917 - val_loss: 0.0853 - learning_rate: 1.0000e-05
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9970 - loss: 0.0666 - val_accuracy: 0.9917 - val_loss: 0.0856 - learning_rate: 1.0000e-05
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9962 - loss: 0.0601 - val_accuracy: 0.9917 - val_loss: 0.0853 - learning_rate: 1.0000e-05
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9982 - loss: 0.0630 - val_accuracy: 0.9917 - val_loss: 0.0851 - learning_rate: 1.0000e-05
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9959 - loss: 0.0705 - val_accuracy: 0.9917 - val_loss: 0.0849 - learning_rate: 1.0000e-05
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9993 - loss: 0.0673 - val_accuracy: 0.9917 - val_loss: 0.0847 - learning_rate: 1.0000e-05
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9985 - loss: 0.0634 - val_accuracy: 0.9917 - val_loss: 0.0849 - learning_rate: 1.0000e-05
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9988 - loss: 0.0612 - val_accuracy: 0.9917 - val_loss: 0.0849 - learning_rate: 1.0000e-05
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9968 - loss: 0.0644 - val_accuracy: 0.9917 - val_loss: 0.0844 - learning_rate: 1.0000e-05
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9967 - loss: 0.0664 - val_accuracy: 0.9917 - val_loss: 0.0845 - learning_rate: 1.0000e-05
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9984 - loss: 0.0691 - val_accuracy: 0.9917 - val_loss: 0.0845 - learning_rate: 1.0000e-05
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9976 - loss: 0.0635 - val_accuracy: 0.9917 - val_loss: 0.0847 - learning_rate: 1.0000e-05
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9985 - loss: 0.0613 - val_accuracy: 0.9917 - val_loss: 0.0843 - learning_rate: 1.0000e-05
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9978 - loss: 0.0632 - val_accuracy: 0.9917 - val_loss: 0.0842 - learning_rate: 1.0000e-05
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9965 - loss: 0.0661 - val_accuracy: 0.9917 - val_loss: 0.0841 - learning_rate: 1.0000e-05
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9961 - loss: 0.0650 - val_accuracy: 0.9917 - val_loss: 0.0838 - learning_rate: 1.0000e-05
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9948 - loss: 0.0704 - val_accuracy: 0.9917 - val_loss: 0.0838 - learning_rate: 1.0000e-05
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9952 - loss: 0.0693 - val_accuracy: 0.9917 - val_loss: 0.0838 - learning_rate: 1.0000e-05
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9947 - loss: 0.0643 - val_accuracy: 0.9917 - val_loss: 0.0839 - learning_rate: 1.0000e-05
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9967 - loss: 0.0688 - val_accuracy: 0.9917 - val_loss: 0.0836 - learning_rate: 1.0000e-05
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9982 - loss: 0.0632 - val_accuracy: 0.9917 - val_loss: 0.0837 - learning_rate: 1.0000e-05
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9953 - loss: 0.0697 - val_accuracy: 0.9917 - val_loss: 0.0834 - learning_rate: 1.0000e-05
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9976 - loss: 0.0658 - val_accuracy: 0.9917 - val_loss: 0.0831 - learning_rate: 1.0000e-05
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9975 - loss: 0.0654 - val_accuracy: 0.9917 - val_loss: 0.0832 - learning_rate: 1.0000e-05
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9986 - loss: 0.0571 - val_accuracy: 0.9917 - val_loss: 0.0833 - learning_rate: 1.0000e-05
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9964 - loss: 0.0664 - val_accuracy: 0.9917 - val_loss: 0.0832 - learning_rate: 1.0000e-05
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9965 - loss: 0.0650 - val_accuracy: 0.9917 - val_loss: 0.0829 - learning_rate: 1.0000e-05
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9983 - loss: 0.0627 - val_accuracy: 0.9917 - val_loss: 0.0828 - learning_rate: 1.0000e-05
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9976 - loss: 0.0662 - val_accuracy: 0.9917 - val_loss: 0.0827 - learning_rate: 1.0000e-05
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9974 - loss: 0.0696 - val_accuracy: 0.9917 - val_loss: 0.0826 - learning_rate: 1.0000e-05
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9987 - loss: 0.0644 - val_accuracy: 0.9917 - val_loss: 0.0828 - learning_rate: 1.0000e-05
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9958 - loss: 0.0639 - val_accuracy: 0.9917 - val_loss: 0.0825 - learning_rate: 1.0000e-05
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9963 - loss: 0.0658 - val_accuracy: 0.9917 - val_loss: 0.0823 - learning_rate: 1.0000e-05
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9974 - loss: 0.0606 - val_accuracy: 0.9917 - val_loss: 0.0824 - learning_rate: 1.0000e-05
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9988 - loss: 0.0644 - val_accuracy: 0.9917 - val_loss: 0.0825 - learning_rate: 1.0000e-05
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9976 - loss: 0.0668 - val_accuracy: 0.9917 - val_loss: 0.0821 - learning_rate: 1.0000e-05
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9979 - loss: 0.0619 - val_accuracy: 0.9917 - val_loss: 0.0820 - learning_rate: 1.0000e-05
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9991 - loss: 0.0660 - val_accuracy: 0.9917 - val_loss: 0.0819 - learning_rate: 1.0000e-05
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9968 - loss: 0.0655 - val_accuracy: 0.9917 - val_loss: 0.0821 - learning_rate: 1.0000e-05
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9988 - loss: 0.0614 - val_accuracy: 0.9917 - val_loss: 0.0815 - learning_rate: 1.0000e-05
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9992 - loss: 0.0596 - val_accuracy: 0.9917 - val_loss: 0.0816 - learning_rate: 1.0000e-05
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9771 - loss: 0.0857
# Test Loss: 0.0832306444644928
# Test Accuracy: 0.9833333492279053

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Plot the training and validation accuracy
plt.figure(figsize=(7, 4))
plt.plot(range(len(history.history['accuracy'])), history.history['accuracy'], label='Training Accuracy')
plt.plot(range(len(history.history['val_accuracy'])), history.history['val_accuracy'], label='Validation Accuracy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# Plot the training and validation loss
plt.figure(figsize=(7, 4))
plt.plot(range(len(history.history['loss'])), history.history['loss'], label='Training Loss')
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], label='Validation Loss')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Make predictions on the test dataset
y_true = []
y_pred = []

for image_batch, label_batch in test_ds:
    predictions = model.predict(image_batch)
    y_true.extend(label_batch.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))  # Get predicted labels

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_true, y_pred)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(11, 12))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.xticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names, rotation=90)
plt.yticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 55s 28s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
# Print the classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Classification Report:
#                      precision    recall  f1-score   support
#
# Ph_alexandri_female       1.00      1.00      1.00        29
#   Ph_alexandri_male       1.00      1.00      1.00        27
#  Ph_papatasi_female       1.00      1.00      1.00        28
#    Ph_papatasi_male       0.96      0.93      0.94        27
#  Ph_sergenti_female       1.00      1.00      1.00        32
#    Ph_sergenti_male       0.95      0.97      0.96        37
#
#            accuracy                           0.98       180
#           macro avg       0.98      0.98      0.98       180
#        weighted avg       0.98      0.98      0.98       180

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, jaccard_score
from sklearn.preprocessing import label_binarize

# Make predictions on the test dataset
y_true = []
y_pred = []
y_scores = []  # For ROC curves (probabilities)

for image_batch, label_batch in test_ds:
    predictions = model.predict(image_batch)
    y_true.extend(label_batch.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))  # Predicted class indices
    y_scores.extend(predictions)  # Keep probabilities for ROC

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_scores = np.array(y_scores)

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_true, y_pred)


# Print the classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# -----------------------------
# Compute and plot ROC curves and AUC for each class
# -----------------------------

# Binarize the output for multiclass ROC
y_true_bin = label_binarize(y_true, classes=np.arange(len(class_names)))

plt.figure(figsize=(10, 8))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.title('Class-wise ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Ph_alexandri_female       1.00      1.00      1.00        29
#   Ph_alexandri_male       1.00      1.00      1.00        27
#  Ph_papatasi_female       1.00      1.00      1.00        28
#    Ph_papatasi_male       0.96      0.93      0.94        27
#  Ph_sergenti_female       1.00      1.00      1.00        32
#    Ph_sergenti_male       0.95      0.97      0.96        37
#
#            accuracy                           0.98       180
#           macro avg       0.98      0.98      0.98       180
#        weighted avg       0.98      0.98      0.98       180

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, jaccard_score
from sklearn.preprocessing import label_binarize

# Make predictions on the test dataset
y_true = []
y_pred = []
y_scores = []  # For ROC curves (probabilities)

for image_batch, label_batch in test_ds:
    predictions = model.predict(image_batch)
    y_true.extend(label_batch.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))  # Predicted class indices
    y_scores.extend(predictions)  # Keep probabilities for ROC

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_scores = np.array(y_scores)

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_true, y_pred)

# Print the classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# -----------------------------
# Compute and plot ROC curves and manual AUC for each class
# -----------------------------

# Binarize the output for multiclass ROC
y_true_bin = label_binarize(y_true, classes=np.arange(len(class_names)))

plt.figure(figsize=(10, 8))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])

    # Use np.trapezoid instead of deprecated np.trapz
    roc_auc_manual = np.trapezoid(tpr, fpr)

    plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc_manual:.3f})')


plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.title('Class-wise ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Ph_alexandri_female       1.00      1.00      1.00        29
#   Ph_alexandri_male       1.00      1.00      1.00        27
#  Ph_papatasi_female       1.00      1.00      1.00        28
#    Ph_papatasi_male       0.96      0.93      0.94        27
#  Ph_sergenti_female       1.00      1.00      1.00        32
#    Ph_sergenti_male       0.95      0.97      0.96        37
#
#            accuracy                           0.98       180
#           macro avg       0.98      0.98      0.98       180
#        weighted avg       0.98      0.98      0.98       180

# %%
# -----------------------------
# Compute Jaccard similarity score per class
# -----------------------------

print("\nJaccard Similarity Scores per Class:")

for i, class_name in enumerate(class_names):
    # Jaccard requires binary vectors: treat class i as positive class
    y_true_binary = (y_true == i).astype(int)
    y_pred_binary = (y_pred == i).astype(int)
    jaccard = jaccard_score(y_true_binary, y_pred_binary)
    print(f"{class_name}: {jaccard:.4f}")
# Out:
# Jaccard Similarity Scores per Class:
# Ph_alexandri_female: 1.0000
# Ph_alexandri_male: 1.0000
# Ph_papatasi_female: 1.0000
# Ph_papatasi_male: 0.8929
# Ph_sergenti_female: 1.0000
# Ph_sergenti_male: 0.9231
